# %% [markdown]
# <a href="https://colab.research.google.com/github/robcovino/MSDAP_notebooks/blob/main/Clustering1_K_means_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 1. My first clustering with K-means

# %%
from sklearn.datasets import make_blobs
X,y = make_blobs(centers=2, n_samples=200, random_state=0, cluster_std=0.3)
print(X[:10],y[:10])
# Out:
# [[2.28526648 1.00455151]
#  [1.93543281 1.00868043]
#  [2.37582034 0.76164792]
#  [1.86403641 0.77848212]
#  [1.43610384 4.74459496]
#  [0.77453194 4.19592138]
#  [1.01948315 4.74006938]
#  [0.70993435 3.70954839]
#  [2.01540335 0.8083264 ]
#  [0.48721057 4.442622  ]] [1 1 1 1 0 0 0 0 1 0]

# %% [markdown]
# Q1. Plot these data sets. What do centers and cluster_std control?

# %% [markdown]
# Now produce a data set with 4 clusters.

# %% [markdown]
# The scikit-learn library has an implementation of the k-means algorithm. Let's apply it to a set of randomly generated blobs, whose labels we throw away.

# %%
from sklearn.cluster import KMeans
model = KMeans(2)
model.fit(X)
print(model.cluster_centers_)
# Out:
# [[2.01065662 0.860252  ]
#  [0.96994584 4.33994543]]

# %% [markdown]
# Q2. What does the argument of KMeans control?

# %%
plt.scatter(X[:,0],X[:,1], c=model.labels_);
plt.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], s=100, color="red"); # Show the centres

# %% [markdown]
# The clustering looks more or less correct. To get a more quantitative measure of success we can get the accuracy score.

# %%
from sklearn.metrics import accuracy_score
acc=accuracy_score(y, model.labels_)
print("Accuracy score is", acc)
# Out:
# Accuracy score is 0.0

# %% [markdown]
# Q3. Does this accuracy score make sense to you? If not, what has possibly gotten wrong?

# %% [markdown]
# A3. Even though the clusters could match almost perfectly to the original, their labels might be permuted. Let's select randomly one point from each cluster and check their labels from the original data labels. Then we use this label for the whole cluster. In essence, we are renaming the clusters, not re-clustering the data.

# %%
import scipy
def find_permutation(n_clusters, real_labels, labels):
    permutation=[]
    for i in range(n_clusters):
        idx = labels == i
        new_label=scipy.stats.mode(real_labels[idx])[0][0]  # Choose the most common label among data points in the cluster
        permutation.append(new_label)
    return permutation

# %%
permutation = find_permutation(2, y, model.labels_)
print(permutation)
# Out:
# [1, 0]

# %%
new_labels = [ permutation[label] for label in model.labels_]   # permute the labels
print("Accuracy score is", accuracy_score(y, new_labels))
# Out:
# Accuracy score is 1.0

# %% [markdown]
# Q4. Check how the accuracy score depends on the cluster_std parameter.

# %%
X,y = make_blobs(centers=4, n_samples=200, random_state=0, cluster_std=0.9)
model = KMeans(4)
model.fit(X)
plt.scatter(X[:,0],X[:,1], c=model.labels_);
plt.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], s=100, color="red"); # Show the centres

# %% [markdown]
# Q5. What happens if you initialize K-means with a wrong number of clusters hyper-parameter?

# %%
X,y = make_blobs(centers=4, n_samples=200, random_state=0, cluster_std=0.6)
model = KMeans(3)
model.fit(X)
plt.scatter(X[:,0],X[:,1], c=model.labels_);
plt.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], s=100, color="red"); # Show the centres

# %% [markdown]
# Let's change our data type.

# %%
from sklearn.datasets import make_moons
X,y = make_moons(200, noise=0.05, random_state=0)

# %%
plt.scatter(X[:,0], X[:,1]);

# %% [markdown]
# Q6. What is the main difference with the previous data type?
#
# Q7. Identify the clusters by using K-means.

# %%
model=KMeans(2)
model.fit(X)
plt.scatter(X[:,0], X[:,1], c=model.labels_);

# %% [markdown]
# Let's try a different clustering technique: DBSCAN.

# %%
from sklearn.cluster import DBSCAN
model = DBSCAN(eps=0.3)
model.fit(X)
plt.scatter(X[:,0], X[:,1], c=model.labels_);

# %% [markdown]
# Q8. Cluster the preivous data structure with DBSCAN.
#
# Q9. Do you still have to prescribe the number of clusters?

# %% [markdown]
# ## 2. Clustering digits with K-means
#
# Using scikit-learn we can download a set of 1797 images of handwritten digits with the correct labels 0,1,...,9. The images have quite a low resolution: 8*8=64 pixels. Let's see how our machine learning method works with this kind of data.

# %%
from sklearn.datasets import load_digits
digits = load_digits()
digits.data.shape
# Out:
# (1797, 64)

# %% [markdown]
# let's plot the first 10 of them.

# %%
fig, axes = plt.subplots(2,5, subplot_kw=dict(xticks=[], yticks=[]))
for ax, digit in zip(axes.flat, digits.data[:10]):
    ax.imshow(digit.reshape(8,8), cmap="gray")

# %% [markdown]
# Q10. Cluster the pictures of the digits using K-means, visualize the cluster centers, and calculate the accuracy of the clustering.

# %%
model=KMeans(n_clusters = 10, random_state=0)
model.fit(digits.data)
model.cluster_centers_.shape
# Out:
# (10, 64)

# %%
fig, axes = plt.subplots(2,5, subplot_kw=dict(xticks=[], yticks=[]))
for ax, digit in zip(axes.flat, model.cluster_centers_):
    ax.imshow(digit.reshape(8,8), cmap="gray")

# %%
permutation3 = find_permutation(10, digits.target, model.labels_)
print(permutation3)
acc = accuracy_score(digits.target, [ permutation3[label] for label in model.labels_])
print("Accuracy score is", acc)
# Out:
# [4, 3, 5, 9, 7, 0, 1, 8, 2, 6]
# Accuracy score is 0.7935447968836951

# %% [markdown]
# Notebook based on:
#
# https://colab.research.google.com/github/csmastersUH/data_analysis_with_python_spring_2020/blob/master/clustering.ipynb#scrollTo=blpDjoE_FOuu
